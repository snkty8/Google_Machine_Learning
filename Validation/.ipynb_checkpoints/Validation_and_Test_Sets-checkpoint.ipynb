# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
train_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")
test_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_test.csv")

# %%
scale_factor = 1000.0

# Scale the training set's label.
train_df["median_house_value"] /= scale_factor 

# Scale the test set's label
test_df["median_house_value"] /= scale_factor

# %%
#Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Add one linear layer to the model to yield a simple linear regressor.
  model.add(tf.keras.layers.Dense(units=1, input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model               


def train_model(model, df, feature, label, my_epochs, 
                my_batch_size=None, my_validation_split=0.1):
  """Feed a dataset into the model in order to train it."""

  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=my_batch_size,
                      epochs=my_epochs,
                      validation_split=my_validation_split)

  # Gather the model's trained weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the 
  # rest of history.
  epochs = history.epoch
  
  # Isolate the root mean squared error for each epoch.
  hist = pd.DataFrame(history.history)
  rmse = hist["root_mean_squared_error"]

  return epochs, rmse, history.history   

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
#Define the plotting function

def plot_the_loss_curve(epochs, mae_training, mae_validation):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs[1:], mae_training[1:], label="Training Loss")
  plt.plot(epochs[1:], mae_validation[1:], label="Validation Loss")
  plt.legend()
  
  # We're not going to plot the first epoch, since the loss on the first epoch
  # is often substantially greater than the loss for other epochs.
  merged_mae_lists = mae_training[1:] + mae_validation[1:]
  highest_loss = max(merged_mae_lists)
  lowest_loss = min(merged_mae_lists)
  delta = highest_loss - lowest_loss
  print(delta)

  top_of_y_axis = highest_loss + (delta * 0.05)
  bottom_of_y_axis = lowest_loss - (delta * 0.05)
   
  plt.ylim([bottom_of_y_axis, top_of_y_axis])
  plt.show()  

print("Defined the plot_the_loss_curve function.")
# Out:
# Defined the plot_the_loss_curve function.

# %% [markdown]
# Task 1: Experiment with the validation split
# In the following code cell, you'll see a variable named validation_split, which we've initialized at 0.2. The validation_split variable specifies the proportion of the original training set that will serve as the validation set. The original training set contains 17,000 examples. Therefore, a validation_split of 0.2 means that:
#
# 17,000 * 0.2 ~= 3,400 examples will become the validation set.
# 17,000 * 0.8 ~= 13,600 examples will become the new training set.
# The following code builds a model, trains it on the training set, and evaluates the built model on both:
#
# The training set.
# And the validation set.
# If the data in the training set is similar to the data in the validation set, then the two loss curves and the final loss values should be almost identical. However, the loss curves and final loss values are not almost identical. Hmm, that's odd.
#
# Experiment with two or three different values of validation_split. Do different values of validation_split fix the problem?

# %%
# The following variables are the hyperparameters.
learning_rate = 0.08
epochs = 30
batch_size = 100

# Split the original training set into a reduced training set and a
# validation set. 
validation_split = 0.2

# Identify the feature and the label.
my_feature = "median_income"    # the median income on a specific city block.
my_label = "median_house_value" # the median house value on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions to build and train the model.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# C:\Users\snkty\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/30
# 136/136 [==============================] - 1s 4ms/step - loss: 40468.7500 - root_mean_squared_error: 201.1685 - val_loss: 49076.6055 - val_root_mean_squared_error: 221.5324
# Epoch 2/30
# 136/136 [==============================] - 0s 2ms/step - loss: 23363.2109 - root_mean_squared_error: 152.8503 - val_loss: 28758.2754 - val_root_mean_squared_error: 169.5827
# Epoch 3/30
# 136/136 [==============================] - 0s 2ms/step - loss: 12372.3574 - root_mean_squared_error: 111.2311 - val_loss: 15603.0586 - val_root_mean_squared_error: 124.9122
# Epoch 4/30
# 136/136 [==============================] - 0s 2ms/step - loss: 7301.4199 - root_mean_squared_error: 85.4483 - val_loss: 9549.3770 - val_root_mean_squared_error: 97.7209
# Epoch 5/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6512.8540 - root_mean_squared_error: 80.7023 - val_loss: 9369.1572 - val_root_mean_squared_error: 96.7944
# Epoch 6/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.0669 - root_mean_squared_error: 80.7036 - val_loss: 9346.6143 - val_root_mean_squared_error: 96.6779
# Epoch 7/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.6870 - root_mean_squared_error: 80.7074 - val_loss: 9246.4277 - val_root_mean_squared_error: 96.1583
# Epoch 8/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.0381 - root_mean_squared_error: 80.7034 - val_loss: 9369.6533 - val_root_mean_squared_error: 96.7970
# Epoch 9/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6512.8970 - root_mean_squared_error: 80.7025 - val_loss: 9374.8887 - val_root_mean_squared_error: 96.8240
# Epoch 10/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.1313 - root_mean_squared_error: 80.7040 - val_loss: 9317.1133 - val_root_mean_squared_error: 96.5252
# Epoch 11/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6512.9580 - root_mean_squared_error: 80.7029 - val_loss: 9368.4043 - val_root_mean_squared_error: 96.7905
# Epoch 12/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.5083 - root_mean_squared_error: 80.7063 - val_loss: 9157.7988 - val_root_mean_squared_error: 95.6964
# Epoch 13/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.0586 - root_mean_squared_error: 80.7035 - val_loss: 9168.3311 - val_root_mean_squared_error: 95.7514
# Epoch 14/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.1025 - root_mean_squared_error: 80.7038 - val_loss: 9168.0781 - val_root_mean_squared_error: 95.7501
# Epoch 15/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6514.1045 - root_mean_squared_error: 80.7100 - val_loss: 9295.8721 - val_root_mean_squared_error: 96.4151
# Epoch 16/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.7925 - root_mean_squared_error: 80.7081 - val_loss: 9255.1475 - val_root_mean_squared_error: 96.2037
# Epoch 17/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6512.5459 - root_mean_squared_error: 80.7003 - val_loss: 9229.2607 - val_root_mean_squared_error: 96.0690
# Epoch 18/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.4316 - root_mean_squared_error: 80.7058 - val_loss: 9262.2607 - val_root_mean_squared_error: 96.2406
# Epoch 19/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.3247 - root_mean_squared_error: 80.7052 - val_loss: 9347.9570 - val_root_mean_squared_error: 96.6848
# Epoch 20/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.5381 - root_mean_squared_error: 80.7065 - val_loss: 9230.2305 - val_root_mean_squared_error: 96.0741
# Epoch 21/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.4570 - root_mean_squared_error: 80.7060 - val_loss: 9264.6650 - val_root_mean_squared_error: 96.2531
# Epoch 22/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6514.0210 - root_mean_squared_error: 80.7095 - val_loss: 9259.7568 - val_root_mean_squared_error: 96.2276
# Epoch 23/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.7124 - root_mean_squared_error: 80.7076 - val_loss: 9355.2324 - val_root_mean_squared_error: 96.7224
# Epoch 24/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.5366 - root_mean_squared_error: 80.7065 - val_loss: 9182.1543 - val_root_mean_squared_error: 95.8236
# Epoch 25/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6512.5239 - root_mean_squared_error: 80.7002 - val_loss: 9133.5918 - val_root_mean_squared_error: 95.5698
# Epoch 26/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6514.0068 - root_mean_squared_error: 80.7094 - val_loss: 9234.3711 - val_root_mean_squared_error: 96.0956
# Epoch 27/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6512.7783 - root_mean_squared_error: 80.7018 - val_loss: 9325.3906 - val_root_mean_squared_error: 96.5681
# Epoch 28/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6513.4673 - root_mean_squared_error: 80.7061 - val_loss: 9306.8750 - val_root_mean_squared_error: 96.4721
# Epoch 29/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6514.4346 - root_mean_squared_error: 80.7120 - val_loss: 9303.9121 - val_root_mean_squared_error: 96.4568
# Epoch 30/30
# 136/136 [==============================] - 0s 2ms/step - loss: 6512.8008 - root_mean_squared_error: 80.7019 - val_loss: 9210.4404 - val_root_mean_squared_error: 95.9710
# 88.8824462890625

# %% [markdown]
# Task 2: Determine why the loss curves differ
# No matter how you split the training set and the validation set, the loss curves differ significantly. Evidently, the data in the training set isn't similar enough to the data in the validation set. Counterintuitive? Yes, but this problem is actually pretty common in machine learning.
#
# Your task is to determine why the loss curves aren't highly similar. As with most issues in machine learning, the problem is rooted in the data itself. To solve this mystery of why the training set and validation set aren't almost identical, write a line or two of pandas code in the following code cell. Here are a couple of hints:
#
# The previous code cell split the original training set into:
# a reduced training set (the original training set - the validation set)
# the validation set
# By default, the pandas head method outputs the first 5 rows of the DataFrame. To see more of the training set, specify the n argument to head and assign a large positive integer to n.
# [ ]

# %%
#Double-click for a possible solution to Task 2.

# Examine examples 0 through 4 and examples 25 through 29
# of the training set
train_df.head(n=1000)

# The original training set is sorted by longitude. 
# Apparently, longitude influences the relationship of
# total_rooms to median_house_value.
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -114.3      34.2                15.0       5612.0          1283.0
# 1       -114.5      34.4                19.0       7650.0          1901.0
# 2       -114.6      33.7                17.0        720.0           174.0
# 3       -114.6      33.6                14.0       1501.0           337.0
# 4       -114.6      33.6                20.0       1454.0           326.0
# ..         ...       ...                 ...          ...             ...
# 995     -117.1      32.5                 8.0       6533.0          1217.0
# 996     -117.1      34.6                 6.0       5110.0          1044.0
# 997     -117.1      34.2                22.0       4397.0           931.0
# 998     -117.1      34.0                24.0       4144.0           826.0
# 999     -117.1      33.6                 6.0       1868.0           289.0
#
#      population  households  median_income  median_house_value
# 0        1015.0       472.0            1.5                66.9
# 1        1129.0       463.0            1.8                80.1
# 2         333.0       117.0            1.7                85.7
# 3         515.0       226.0            3.2                73.4
# 4         624.0       262.0            1.9                65.5
# ..          ...         ...            ...                 ...
# 995      4797.0      1177.0            4.0               144.4
# 996      1938.0       724.0            3.2               112.8
# 997      1145.0       445.0            4.5               108.4
# 998      2127.0       772.0            2.5                96.0
# 999       750.0       247.0            4.4               307.6
#
# [1000 rows x 9 columns]

# %% [markdown]
# Task 3. Fix the problem
# To fix the problem, shuffle the examples in the training set before splitting the examples into a training set and validation set. To do so, take the following steps:
#
# Shuffle the data in the training set by adding the following line anywhere before you call train_model (in the code cell associated with Task 1):

# %%
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index))

# %% [markdown]
# Pass shuffled_train_df (instead of train_df) as the second argument to train_model (in the code call associated with Task 1) so that the call becomes as follows:

# %%
#@title Double-click to view the complete implementation.

# The following variables are the hyperparameters.
learning_rate = 0.08
epochs = 70
batch_size = 100

# Split the original training set into a reduced training set and a
# validation set. 
validation_split = 0.2

# Identify the feature and the label.
my_feature = "median_income"    # the median income on a specific city block.
my_label = "median_house_value" # the median house value on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on the neighborhood's median income.  

# Discard any pre-existing version of the model.
my_model = None

# Shuffle the examples.
shuffled_train_df = train_df.reindex(np.random.permutation(train_df.index)) 

# Invoke the functions to build and train the model. Train on the shuffled
# training set.
my_model = build_model(learning_rate)
epochs, rmse, history = train_model(my_model, shuffled_train_df, my_feature, 
                                    my_label, epochs, batch_size, 
                                    validation_split)

plot_the_loss_curve(epochs, history["root_mean_squared_error"], 
                    history["val_root_mean_squared_error"])
# Out:
# C:\Users\snkty\anaconda3\envs\PythonData\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/70
# 136/136 [==============================] - 1s 3ms/step - loss: 43282.4766 - root_mean_squared_error: 208.0444 - val_loss: 32418.0996 - val_root_mean_squared_error: 180.0503
# Epoch 2/70
# 136/136 [==============================] - 0s 2ms/step - loss: 25121.1250 - root_mean_squared_error: 158.4964 - val_loss: 17902.3867 - val_root_mean_squared_error: 133.7998
# Epoch 3/70
# 136/136 [==============================] - 0s 2ms/step - loss: 13501.7480 - root_mean_squared_error: 116.1970 - val_loss: 9561.8154 - val_root_mean_squared_error: 97.7845
# Epoch 4/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7938.6226 - root_mean_squared_error: 89.0989 - val_loss: 6953.1621 - val_root_mean_squared_error: 83.3856
# Epoch 5/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.3413 - root_mean_squared_error: 83.8889 - val_loss: 6922.1543 - val_root_mean_squared_error: 83.1995
# Epoch 6/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.2236 - root_mean_squared_error: 83.8941 - val_loss: 6921.7388 - val_root_mean_squared_error: 83.1970
# Epoch 7/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.3638 - root_mean_squared_error: 83.8950 - val_loss: 6921.2871 - val_root_mean_squared_error: 83.1943
# Epoch 8/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.5469 - root_mean_squared_error: 83.8901 - val_loss: 6921.5806 - val_root_mean_squared_error: 83.1960
# Epoch 9/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.1973 - root_mean_squared_error: 83.8820 - val_loss: 6927.8696 - val_root_mean_squared_error: 83.2338
# Epoch 10/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.3843 - root_mean_squared_error: 83.8832 - val_loss: 6924.1792 - val_root_mean_squared_error: 83.2117
# Epoch 11/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.4795 - root_mean_squared_error: 83.8897 - val_loss: 6922.5400 - val_root_mean_squared_error: 83.2018
# Epoch 12/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.0957 - root_mean_squared_error: 83.8874 - val_loss: 6922.2983 - val_root_mean_squared_error: 83.2003
# Epoch 13/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.9971 - root_mean_squared_error: 83.8868 - val_loss: 6921.9121 - val_root_mean_squared_error: 83.1980
# Epoch 14/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.4888 - root_mean_squared_error: 83.8897 - val_loss: 6922.9302 - val_root_mean_squared_error: 83.2041
# Epoch 15/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.6777 - root_mean_squared_error: 83.8909 - val_loss: 6921.3945 - val_root_mean_squared_error: 83.1949
# Epoch 16/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.0049 - root_mean_squared_error: 83.8928 - val_loss: 6922.3877 - val_root_mean_squared_error: 83.2009
# Epoch 17/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.3589 - root_mean_squared_error: 83.8949 - val_loss: 6921.5845 - val_root_mean_squared_error: 83.1961
# Epoch 18/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.2661 - root_mean_squared_error: 83.8825 - val_loss: 6922.6733 - val_root_mean_squared_error: 83.2026
# Epoch 19/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.0542 - root_mean_squared_error: 83.8872 - val_loss: 6921.5396 - val_root_mean_squared_error: 83.1958
# Epoch 20/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7035.8066 - root_mean_squared_error: 83.8797 - val_loss: 6922.6289 - val_root_mean_squared_error: 83.2023
# Epoch 21/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.0552 - root_mean_squared_error: 83.8931 - val_loss: 6922.3770 - val_root_mean_squared_error: 83.2008
# Epoch 22/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.3193 - root_mean_squared_error: 83.8828 - val_loss: 6921.3853 - val_root_mean_squared_error: 83.1949
# Epoch 23/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.3447 - root_mean_squared_error: 83.8948 - val_loss: 6921.4077 - val_root_mean_squared_error: 83.1950
# Epoch 24/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.4336 - root_mean_squared_error: 83.8894 - val_loss: 6921.7959 - val_root_mean_squared_error: 83.1973
# Epoch 25/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.2935 - root_mean_squared_error: 83.8886 - val_loss: 6924.5068 - val_root_mean_squared_error: 83.2136
# Epoch 26/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.5908 - root_mean_squared_error: 83.8904 - val_loss: 6921.5225 - val_root_mean_squared_error: 83.1957
# Epoch 27/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.0483 - root_mean_squared_error: 83.8871 - val_loss: 6921.7827 - val_root_mean_squared_error: 83.1973
# Epoch 28/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.7422 - root_mean_squared_error: 83.8913 - val_loss: 6921.5464 - val_root_mean_squared_error: 83.1958
# Epoch 29/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.4580 - root_mean_squared_error: 83.8896 - val_loss: 6922.7896 - val_root_mean_squared_error: 83.2033
# Epoch 30/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.5815 - root_mean_squared_error: 83.8903 - val_loss: 6922.2158 - val_root_mean_squared_error: 83.1999
# Epoch 31/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.7847 - root_mean_squared_error: 83.8915 - val_loss: 6924.0210 - val_root_mean_squared_error: 83.2107
# Epoch 32/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.4902 - root_mean_squared_error: 83.8957 - val_loss: 6921.4995 - val_root_mean_squared_error: 83.1955
# Epoch 33/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.7900 - root_mean_squared_error: 83.8856 - val_loss: 6921.8994 - val_root_mean_squared_error: 83.1980
# Epoch 34/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.7417 - root_mean_squared_error: 83.8913 - val_loss: 6922.2041 - val_root_mean_squared_error: 83.1998
# Epoch 35/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.7871 - root_mean_squared_error: 83.8856 - val_loss: 6925.1616 - val_root_mean_squared_error: 83.2176
# Epoch 36/70
# 136/136 [==============================] - 0s 3ms/step - loss: 7038.8618 - root_mean_squared_error: 83.8979 - val_loss: 6921.8057 - val_root_mean_squared_error: 83.1974
# Epoch 37/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.3076 - root_mean_squared_error: 83.8827 - val_loss: 6922.3545 - val_root_mean_squared_error: 83.2007
# Epoch 38/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.9263 - root_mean_squared_error: 83.8923 - val_loss: 6922.3457 - val_root_mean_squared_error: 83.2006
# Epoch 39/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.0488 - root_mean_squared_error: 83.8812 - val_loss: 6922.7959 - val_root_mean_squared_error: 83.2033
# Epoch 40/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.2080 - root_mean_squared_error: 83.8940 - val_loss: 6922.9883 - val_root_mean_squared_error: 83.2045
# Epoch 41/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.0596 - root_mean_squared_error: 83.8931 - val_loss: 6921.6377 - val_root_mean_squared_error: 83.1964
# Epoch 42/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.7993 - root_mean_squared_error: 83.8856 - val_loss: 6921.5435 - val_root_mean_squared_error: 83.1958
# Epoch 43/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7033.1401 - root_mean_squared_error: 83.8638 - val_loss: 6934.6719 - val_root_mean_squared_error: 83.2747
# Epoch 44/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.3052 - root_mean_squared_error: 83.8946 - val_loss: 6923.0864 - val_root_mean_squared_error: 83.2051
# Epoch 45/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.8877 - root_mean_squared_error: 83.8862 - val_loss: 6925.1802 - val_root_mean_squared_error: 83.2177
# Epoch 46/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.4512 - root_mean_squared_error: 83.8895 - val_loss: 6921.9600 - val_root_mean_squared_error: 83.1983
# Epoch 47/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.6733 - root_mean_squared_error: 83.8908 - val_loss: 6921.8765 - val_root_mean_squared_error: 83.1978
# Epoch 48/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.6289 - root_mean_squared_error: 83.8906 - val_loss: 6921.8101 - val_root_mean_squared_error: 83.1974
# Epoch 49/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.5981 - root_mean_squared_error: 83.8904 - val_loss: 6921.4136 - val_root_mean_squared_error: 83.1950
# Epoch 50/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.6123 - root_mean_squared_error: 83.8845 - val_loss: 6923.2109 - val_root_mean_squared_error: 83.2058
# Epoch 51/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.4487 - root_mean_squared_error: 83.8955 - val_loss: 6921.4102 - val_root_mean_squared_error: 83.1950
# Epoch 52/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.0449 - root_mean_squared_error: 83.8931 - val_loss: 6921.5146 - val_root_mean_squared_error: 83.1956
# Epoch 53/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.4766 - root_mean_squared_error: 83.8897 - val_loss: 6922.4893 - val_root_mean_squared_error: 83.2015
# Epoch 54/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.3335 - root_mean_squared_error: 83.8888 - val_loss: 6922.1914 - val_root_mean_squared_error: 83.1997
# Epoch 55/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.7388 - root_mean_squared_error: 83.8912 - val_loss: 6924.8110 - val_root_mean_squared_error: 83.2154
# Epoch 56/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.3760 - root_mean_squared_error: 83.8950 - val_loss: 6921.4575 - val_root_mean_squared_error: 83.1953
# Epoch 57/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7035.2568 - root_mean_squared_error: 83.8764 - val_loss: 6928.6396 - val_root_mean_squared_error: 83.2384
# Epoch 58/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7039.1113 - root_mean_squared_error: 83.8994 - val_loss: 6921.4375 - val_root_mean_squared_error: 83.1952
# Epoch 59/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.3877 - root_mean_squared_error: 83.8891 - val_loss: 6922.8149 - val_root_mean_squared_error: 83.2035
# Epoch 60/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.5942 - root_mean_squared_error: 83.8904 - val_loss: 6922.3818 - val_root_mean_squared_error: 83.2009
# Epoch 61/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.4194 - root_mean_squared_error: 83.8953 - val_loss: 6921.6890 - val_root_mean_squared_error: 83.1967
# Epoch 62/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.5806 - root_mean_squared_error: 83.8903 - val_loss: 6922.1655 - val_root_mean_squared_error: 83.1996
# Epoch 63/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.4609 - root_mean_squared_error: 83.8896 - val_loss: 6921.7905 - val_root_mean_squared_error: 83.1973
# Epoch 64/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.2070 - root_mean_squared_error: 83.8940 - val_loss: 6921.4434 - val_root_mean_squared_error: 83.1952
# Epoch 65/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.2021 - root_mean_squared_error: 83.8821 - val_loss: 6923.8101 - val_root_mean_squared_error: 83.2094
# Epoch 66/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.8286 - root_mean_squared_error: 83.8918 - val_loss: 6921.7349 - val_root_mean_squared_error: 83.1970
# Epoch 67/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.9165 - root_mean_squared_error: 83.8863 - val_loss: 6922.5366 - val_root_mean_squared_error: 83.2018
# Epoch 68/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7037.9849 - root_mean_squared_error: 83.8927 - val_loss: 6924.2119 - val_root_mean_squared_error: 83.2119
# Epoch 69/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7038.3447 - root_mean_squared_error: 83.8948 - val_loss: 6921.4155 - val_root_mean_squared_error: 83.1950
# Epoch 70/70
# 136/136 [==============================] - 0s 2ms/step - loss: 7036.4399 - root_mean_squared_error: 83.8835 - val_loss: 6923.3813 - val_root_mean_squared_error: 83.2069
# 75.30216979980469

# %% [markdown]
# Experiment with validation_split to answer the following questions:
#
# With the training set shuffled, is the final loss for the training set closer to the final loss for the validation set?
# At what range of values of validation_split do the final loss values for the training set and validation set diverge meaningfully? Why?

# %%
#@title Double-click for the answers to the questions

# Yes, after shuffling the original training set, 
# the final loss for the training set and the 
# validation set become much closer.

# If validation_split < 0.15,
# the final loss values for the training set and
# validation set diverge meaningfully.  Apparently,
# the validation set no longer contains enough examples.

# %% [markdown]
# Task 4: Use the Test Dataset to Evaluate Your Model's Performance
# The test set usually acts as the ultimate judge of a model's quality. The test set can serve as an impartial judge because its examples haven't been used in training the model. Run the following code cell to evaluate the model with the test set:

# %%
x_test = test_df[my_feature]
y_test = test_df[my_label]

results = my_model.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 30/30 [==============================] - 0s 2ms/step - loss: 7009.3486 - root_mean_squared_error: 83.7219

# %% [markdown]
# Compare the root mean squared error of the model when evaluated on each of the three datasets:
#
# training set: look for root_mean_squared_error in the final training epoch.
# validation set: look for val_root_mean_squared_error in the final training epoch.
# test set: run the preceding code cell and examine the root_mean_squared_error.
# Ideally, the root mean squared error of all three sets should be similar. Are they?

# %%
#@title Double-click for an answer

# In our experiments, yes, the rmse values 
# were similar enough.
